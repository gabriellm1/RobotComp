# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 3.2.0

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240L, 320L, 3L)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240L, 320L)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
h=plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# ## 1
# A imagem aproveita apenas um range de 50 tons dos 255 que podiam ser aproveitados(19,6%), então o histograma não aproveita bem.

# %% [markdown]
# ## 2 e 3

# %%
print('Valor maximo:{}\nValor mínimo:{}'.format(rintin_gray.max(),rintin_gray.min()))
# Out:
# Valor maximo:58
# Valor mínimo:8

# %%
rintin_gray-=8 # para'empurrar' para origem
rintin_gray*=(255/50) #para equalizar

hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256]) 

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
h=plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %% [markdown]
# ## 1

# %%
caixas = cv2.imread("hall_box_battery1.jpg")
caixas_rgb = cv2.cvtColor(caixas, cv2.COLOR_BGR2RGB)

caixas_r = caixas_rgb[:,:,0] #red
caixas_b = caixas_rgb[:,:,2] #blue

redblue = np.hstack((caixas_r,caixas_b))

plt.imshow(redblue, cmap='Greys_r')

# %%
hist,bins = np.histogram(caixas_rgb.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'r')
h=plt.hist(caixas_rgb.flatten(),256,[0,256], color = 'b')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# Pelos canais é possível se indentificar as cores azul e vermelho mas pelo histograma já não é o mesmo caso. Observando o gráfico não é possível indentificar as caixas.

# %% [markdown]
# ## 2

# %%
caixas_hsv = cv2.cvtColor(caixas, cv2.COLOR_BGR2HSV)

mask = np.array([255,255,255])
vermelho_menor = np.array([0,70, 50])
vermelho_maior = np.array([8, 255, 255])

mask = cv2.inRange(caixas_hsv, vermelho_menor, vermelho_maior)
caixas_rgb[mask == 255] =[0,0,0]
    
plot_final = cv2.bitwise_not(caixas_rgb,caixas_rgb, mask= mask)


plt.imshow(plot_final)
